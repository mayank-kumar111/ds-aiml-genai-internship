# %%
import requests

# %%
url = "https://www.geeksforgeeks.org/"

# %%
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
resp.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><script type="application/ld+json">{"@context":"http://schema.org","@type":"Organization","name":"GeeksforGeeks","url":"https://www.geeksforgeeks.org/","logo":"https://media.geeksforgeeks.org/wp-content/cdn-uploads/20200817185016/gfg_complete_logo_2x-min.png","description":"Your All-in-One Learning Portal. It contains well written, well thought and well explained computer science and programming articles, quizzes and practice/competitive programming/company interview Questions.","founder":[{"@type":"Person","name":"Sandeep Jain","url":"https://in.linkedin.com/in/sandeep-jain-b3940815"}],"sameAs":["https://www.facebook.com/geeksforgeeks.org/","https://twitter.com/geeksforgeeks","https://www.linkedin.com/company/1299009","https://www.youtube.com/geeksforgeeksvideos/"]}</script><link rel="preconnect" href="https://fonts.googleapis.com"/><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="true"/><meta name="viewport" content="width=
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(resp.content)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.h1
# Out:
# <h1>Need help with<br/><span class="HomePageCommunityNudge_gradient-text__fh0bR">Career Guidance?</span></h1>

# %%
soup.h2
# Out:
# <h2 class="HomePageSectionHeader_homePageSectionHeader_heading__HVYsv">Courses</h2>

# %%
soup.h3

# %%
soup.h1
# Out:
# <h1>Need help with<br/><span class="HomePageCommunityNudge_gradient-text__fh0bR">Career Guidance?</span></h1>

# %%
soup.h1.text
# Out:
# 'Need help withCareer Guidance?'

# %%
soup.h1
# Out:
# <h1>Need help with<br/><span class="HomePageCommunityNudge_gradient-text__fh0bR">Career Guidance?</span></h1>

# %%
soup.find_all('h1')
# Out:
# [<h1>Need help with<br/><span class="HomePageCommunityNudge_gradient-text__fh0bR">Career Guidance?</span></h1>]

# %%
soup.div
# Out:
# <div data-reactroot="" id="__next"><div style="visibility:hidden;background-color:#ffffff;min-height:100vh"><div data-overlay-container="true"><style>
#       #nprogress {
#         pointer-events: none;
#       }
#       #nprogress .bar {
#         background: #29D;
#         position: fixed;
#         z-index: 9999;
#         top: 0;
#         left: 0;
#         width: 100%;
#         height: 3px;
#       }
#       #nprogress .peg {
#         display: block;
#         position: absolute;
#         right: 0px;
#         width: 100px;
#         height: 100%;
#         box-shadow: 0 0 10px #29D, 0 0 5px #29D;
#         opacity: 1;
#         -webkit-transform: rotate(3deg) translate(0px, -4px);
#         -ms-transform: rotate(3deg) translate(0px, -4px);
#         transform: rotate(3deg) translate(0px, -4px);
#       }
#       #nprogress .spinner {
#         display: block;
#         position: fixed;
#         z-index: 1031;
#         top: 15px;
#         right: 15px;
#       }
# ...

# %%
soup.find_all("div")
# Out:
# [<div data-reactroot="" id="__next"><div style="visibility:hidden;background-color:#ffffff;min-height:100vh"><div data-overlay-container="true"><style>
#        #nprogress {
#          pointer-events: none;
#        }
#        #nprogress .bar {
#          background: #29D;
#          position: fixed;
#          z-index: 9999;
#          top: 0;
#          left: 0;
#          width: 100%;
#          height: 3px;
#        }
#        #nprogress .peg {
#          display: block;
#          position: absolute;
#          right: 0px;
#          width: 100px;
#          height: 100%;
#          box-shadow: 0 0 10px #29D, 0 0 5px #29D;
#          opacity: 1;
#          -webkit-transform: rotate(3deg) translate(0px, -4px);
#          -ms-transform: rotate(3deg) translate(0px, -4px);
#          transform: rotate(3deg) translate(0px, -4px);
#        }
#        #nprogress .spinner {
#          display: block;
#          position: fixed;
#          z-index: 1031;
#          top: 15px;
# ...

# %%
url = "https://www.amazon.in/s?k=laptops&crid=3B24T9T107UR9&sprefix=laptops%2Caps%2C266&ref=nb_sb_noss_2"

# %%
resp = requests.get(url)
resp
# Out:
# <Response [503]>

# %%
resp.reason
# Out:
# 'Service Unavailable'

# %%
data = resp.content
data
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="preconnect" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="preconnect" href="https://m.media-amazon.com" crossorigin>\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n\n<!-- sp:end-feature:csm:head-open-part2 -->\n<!-- sp:feature:aui-assets -->\n<link rel="stylesheet" href="https://m.media-amazon.com/images/I/21uDPuQuYwL._RC|51SvmD+jTBL.css_.css?AUIClients/AmazonUI" />\n<link rel="stylesheet" href="https://m.media-amazon.com/images/I/11WsGYSItxL._RC|01DE6WSvLKL.css,41ixaNR85ML.css,3182OVlP7IL.css,21JMC7OC9
# ...

# %%
soup = BeautifulSoup(data)
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <!-- sp:end-feature:csm:head-open-part2 -->
# <!-- sp:feature:aui-assets -->
# <link href="https://m.media-amazon.com/images/I/21uDPuQuYwL._RC|51SvmD+jTBL.css_.css?AUIClients/AmazonUI" rel="stylesheet"/>
# ...

# %%
all_h2 = soup.find_all('h2')
all_h2
# Out:
# [<h2 class="nav-assistant-heading nav-assistant-headers-font" id="nav-assistant-links-heading">Skip to</h2>,
#  <h2 class="nav-assistant-heading nav-assistant-headers-font font-color aok-hidden" id="nav-assist-shortcuts-heading">
#        Keyboard shortcuts
#    </h2>,
#  <h2 class="a-size-base a-spacing-small a-spacing-top-small a-text-normal">
#  <span>1-16 of over 60,000 results for</span><span> </span><span class="a-color-state a-text-bold">"laptops"</span>
#  </h2>,
#  <h2 class="a-size-medium-plus a-spacing-none a-color-base a-text-bold">Results</h2>,
# ...

# %%
len(all_h2)
# Out:
# 24

# %%
v = all_h2[4:-3]
v
# Out:
# [<h2 aria-label="ASUS Vivobook 16,Smartchoice, 13th Gen, Intel Core i5-13420H,16GB RAM,512GB SSD,FHD, OLED,Win 11,M365 Basic (1Y),Backlit Keyboard,Office 2024,Silver,1.88 kg,X1605VA-SH1952WS, Thin &amp; Light Laptop" class="a-size-medium a-spacing-none a-color-base a-text-normal"><span>ASUS Vivobook 16,Smartchoice, 13th Gen, Intel Core i5-13420H,16GB RAM,512GB SSD,FHD, OLED,Win 11,M365 Basic (1Y),Backlit Keyboard,Office 2024,Silver,1.88 kg,X1605VA-SH1952WS, Thin &amp; Light Laptop</span></h2>,
#  <h2 aria-label="HP 15, AMD Ryzen 5 7520U,(16GB LPDDR5, 512GB SSD), Anti-Glare, Micro-Edge, FHD, 15.6''/39.6cm, Win 11, Office 24,M365 Basic(1yr)*,Silver, 1.59kg, fc0690au, FHD Camera, Backlit KB Laptop" class="a-size-medium a-spacing-none a-color-base a-text-normal"><span>HP 15, AMD Ryzen 5 7520U,(16GB LPDDR5, 512GB SSD), Anti-Glare, Micro-Edge, FHD, 15.6''/39.6cm, Win 11, Office 24,M365 Basic(1yr)*,Silver, 1.59kg, fc0690au, FHD Camera, Backlit KB Laptop</span></h2>,
# ...

# %%
len(v)
# Out:
# 17

# %%
v[0]
# Out:
# <h2 aria-label="ASUS Vivobook 16,Smartchoice, 13th Gen, Intel Core i5-13420H,16GB RAM,512GB SSD,FHD, OLED,Win 11,M365 Basic (1Y),Backlit Keyboard,Office 2024,Silver,1.88 kg,X1605VA-SH1952WS, Thin &amp; Light Laptop" class="a-size-medium a-spacing-none a-color-base a-text-normal"><span>ASUS Vivobook 16,Smartchoice, 13th Gen, Intel Core i5-13420H,16GB RAM,512GB SSD,FHD, OLED,Win 11,M365 Basic (1Y),Backlit Keyboard,Office 2024,Silver,1.88 kg,X1605VA-SH1952WS, Thin &amp; Light Laptop</span></h2>

# %%
v[0].text
# Out:
# 'ASUS Vivobook 16,Smartchoice, 13th Gen, Intel Core i5-13420H,16GB RAM,512GB SSD,FHD, OLED,Win 11,M365 Basic (1Y),Backlit Keyboard,Office 2024,Silver,1.88 kg,X1605VA-SH1952WS, Thin & Light Laptop'

# %%
for i in v:
    print(i.text)
    print()
# Out:
# ASUS Vivobook 16,Smartchoice, 13th Gen, Intel Core i5-13420H,16GB RAM,512GB SSD,FHD, OLED,Win 11,M365 Basic (1Y),Backlit Keyboard,Office 2024,Silver,1.88 kg,X1605VA-SH1952WS, Thin & Light Laptop
#
# HP 15, AMD Ryzen 5 7520U,(16GB LPDDR5, 512GB SSD), Anti-Glare, Micro-Edge, FHD, 15.6''/39.6cm, Win 11, Office 24,M365 Basic(1yr)*,Silver, 1.59kg, fc0690au, FHD Camera, Backlit KB Laptop
#
# Lenovo V15 G4 AMD Athlon Silver 7120U Laptop 8GB LPDDR5 Ram, 512 GB SSD PCIe, Windows 11 Lifetime Validity,15.6" FHD Screen, AMD Radeon 610M, Silver, 1 Year Brand Warranty
#
# More results
#
# Dell 15, 13th Gen Intel Core i5-1334U (16GB DDR4, 512GB SSD) Anti-Glare FHD 15.6"/39.62cm, Windows 11, Microsoft Office Home 2024, Grey, 1.66kg, [Vostro 3530], 12 Month McAfee, Thin & Light Laptop
#
# Acer Smartchoice Aspire One, Intel Core Celeron N4500, Office 2024 + M365 Basic, 12GB LPDDR4X / 512GB SSD, 14.0"/35.56cm TN HD Display, Win 11 Home, Pure Silver, 1.3KG, A114-45, Thin and Light Laptop
#
# ...

# %%
laptops = []
for i in v:
    laptops.append(i.text)

# %%
print(laptops)
# Out:
# ['ASUS Vivobook 16,Smartchoice, 13th Gen, Intel Core i5-13420H,16GB RAM,512GB SSD,FHD, OLED,Win 11,M365 Basic (1Y),Backlit Keyboard,Office 2024,Silver,1.88 kg,X1605VA-SH1952WS, Thin & Light Laptop', "HP 15, AMD Ryzen 5 7520U,(16GB LPDDR5, 512GB SSD), Anti-Glare, Micro-Edge, FHD, 15.6''/39.6cm, Win 11, Office 24,M365 Basic(1yr)*,Silver, 1.59kg, fc0690au, FHD Camera, Backlit KB Laptop", 'Lenovo V15 G4 AMD Athlon Silver 7120U Laptop 8GB LPDDR5 Ram, 512 GB SSD PCIe, Windows 11 Lifetime Validity,15.6" FHD Screen, AMD Radeon 610M, Silver, 1 Year Brand Warranty', 'More results', 'Dell 15, 13th Gen Intel Core i5-1334U (16GB DDR4, 512GB SSD) Anti-Glare FHD 15.6"/39.62cm, Windows 11, Microsoft Office Home 2024, Grey, 1.66kg, [Vostro 3530], 12 Month McAfee, Thin & Light Laptop', 'Acer Smartchoice Aspire One, Intel Core Celeron N4500, Office 2024 + M365 Basic, 12GB LPDDR4X / 512GB SSD, 14.0"/35.56cm TN HD Display, Win 11 Home, Pure Silver, 1.3KG, A114-45, Thin and Light Laptop', 'Dell 15 (Previo
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <!-- sp:end-feature:csm:head-open-part2 -->
# <!-- sp:feature:aui-assets -->
# <link href="https://m.media-amazon.com/images/I/21uDPuQuYwL._RC|51SvmD+jTBL.css_.css?AUIClients/AmazonUI" rel="stylesheet"/>
# ...

# %%
soup.find_all("div")
# Out:
# [<div id="a-page"><script data-a-state='{"key":"a-wlab-states"}' type="a-state">{"AUI_72554":"C","AUI_TEMPLATE_WEBLAB_CACHE_333406":"C"}</script><script>typeof uex === 'function' && uex('ld', 'portal-bb', {wb: 1})</script><!-- sp:end-feature:start-body -->
#  <!-- sp:feature:csm:body-open -->
#  <!-- sp:end-feature:csm:body-open -->
#  <!-- sp:feature:nav-inline-js -->
#  <!-- NAVYAAN JS -->
# ...

# %%
a-row a-size-small
a-row a-size-small

# %%
all_divs = soup.find_all("div", attrs={'class':'a-row a-size-small'})
all_divs
# Out:
# [<div class="a-row a-size-small"><span aria-hidden="true" class="a-size-small a-color-base">4.2</span><span class="a-declarative" data-a-popover='{"url":"/review/widgets/average-customer-review/popover/ref=acr_search__popover?ie=UTF8&amp;asin=B0FN9WN6XD&amp;ref=acr_search__popover&amp;contextId=search","position":"triggerBottom","closeButton":true,"popoverLabel":"4.2 out of 5 stars, rating details","closeButtonLabel":""}' data-action="a-popover" data-csa-c-func-deps="aui-da-a-popover" data-csa-c-type="widget" data-render-id="ryyc7hil5sj052viijqwvqv03t" data-version-id="v2lstc5p0oad1j2pqjic4rhsbvr"><a aria-label="4.2 out of 5 stars, rating details" class="a-popover-trigger a-declarative mvt-review-star-mini-popover" href="javascript:void(0)" role="button"><i aria-hidden="true" class="a-icon a-icon-star-mini a-star-mini-4 mvt-review-star-mini mvt-review-star-with-margin" data-cy="reviews-ratings-slot"><span class="a-icon-alt">4.2 out of 5 stars</span></i><i class="a-icon a-icon-popover
# ...

# %%
len(all_divs)
# Out:
# 13

# %%
all_divs[0]
# Out:
# <div class="a-row a-size-small"><span aria-hidden="true" class="a-size-small a-color-base">4.2</span><span class="a-declarative" data-a-popover='{"url":"/review/widgets/average-customer-review/popover/ref=acr_search__popover?ie=UTF8&amp;asin=B0FN9WN6XD&amp;ref=acr_search__popover&amp;contextId=search","position":"triggerBottom","closeButton":true,"popoverLabel":"4.2 out of 5 stars, rating details","closeButtonLabel":""}' data-action="a-popover" data-csa-c-func-deps="aui-da-a-popover" data-csa-c-type="widget" data-render-id="ryyc7hil5sj052viijqwvqv03t" data-version-id="v2lstc5p0oad1j2pqjic4rhsbvr"><a aria-label="4.2 out of 5 stars, rating details" class="a-popover-trigger a-declarative mvt-review-star-mini-popover" href="javascript:void(0)" role="button"><i aria-hidden="true" class="a-icon a-icon-star-mini a-star-mini-4 mvt-review-star-mini mvt-review-star-with-margin" data-cy="reviews-ratings-slot"><span class="a-icon-alt">4.2 out of 5 stars</span></i><i class="a-icon a-icon-popover"
# ...

# %%
all_divs[0].text
# Out:
# '4.24.2 out of 5 stars (777)  '

# %%
all_span = soup.find_all('span', attrs={'class':'a-size-small a-color-base'})
all_span
# Out:
# [<span aria-hidden="true" class="a-size-small a-color-base">4.2</span>,
#  <span aria-hidden="true" class="a-size-small a-color-base">4.0</span>,
#  <span aria-hidden="true" class="a-size-small a-color-base">4.0</span>,
#  <span aria-hidden="true" class="a-size-small a-color-base">3.8</span>,
#  <span aria-hidden="true" class="a-size-small a-color-base">3.3</span>,
#  <span aria-hidden="true" class="a-size-small a-color-base">4.0</span>,
#  <span aria-hidden="true" class="a-size-small a-color-base">4.2</span>,
#  <span aria-hidden="true" class="a-size-small a-color-base">4.8</span>,
#  <span aria-hidden="true" class="a-size-small a-color-base">4.1</span>,
#  <span aria-hidden="true" class="a-size-small a-color-base">3.4</span>,
#  <span aria-hidden="true" class="a-size-small a-color-base">4.1</span>,
#  <span aria-hidden="true" class="a-size-small a-color-base">3.7</span>,
#  <span aria-hidden="true" class="a-size-small a-color-base">2.7</span>,
# ...

# %%
all_span[0].text
# Out:
# '4.2'

# %%
for span in all_span:
    print(span.text)
# Out:
# 4.2
# 4.0
# 4.0
# 3.8
# 3.3
# 4.0
# 4.2
# 4.8
# 4.1
# 3.4
# 4.1
# 3.7
# 2.7
# & Up

# %%
ratings = []
for span in all_span:
    ratings.append(span.text)

# %%
ratings
# Out:
# ['4.2',
#  '4.0',
#  '4.0',
#  '3.8',
#  '3.3',
#  '4.0',
#  '4.2',
#  '4.8',
#  '4.1',
#  '3.4',
#  '4.1',
#  '3.7',
#  '2.7',
#  '& Up']

# %%
prices = soup.find_all('span', attrs={'class':'a-price-whole'})
prices
# Out:
# [<span class="a-price-whole">63,990</span>,
#  <span class="a-price-whole">54,690</span>,
#  <span class="a-price-whole">43,999</span>,
#  <span class="a-price-whole">59,990</span>,
#  <span class="a-price-whole">39,990</span>,
#  <span class="a-price-whole">50,490</span>,
#  <span class="a-price-whole">72,120</span>,
#  <span class="a-price-whole">49,480</span>,
#  <span class="a-price-whole">68,990</span>,
#  <span class="a-price-whole">63,990</span>,
#  <span class="a-price-whole">49,750</span>,
#  <span class="a-price-whole">41,990</span>,
#  <span class="a-price-whole">16,990</span>,
#  <span class="a-price-whole">86,990</span>,
#  <span class="a-price-whole">64,990</span>,
#  <span class="a-price-whole">30,990</span>]

# %%
for i in prices:
    print(i.text)
# Out:
# 63,990
# 54,690
# 43,999
# 59,990
# 39,990
# 50,490
# 72,120
# 49,480
# 68,990
# 63,990
# 49,750
# 41,990
# 16,990
# 86,990
# 64,990
# 30,990

# %%
price = []
for i in prices:
    price.append(i.text)

# %%
print(laptops)
# Out:
# ['ASUS Vivobook 16,Smartchoice, 13th Gen, Intel Core i5-13420H,16GB RAM,512GB SSD,FHD, OLED,Win 11,M365 Basic (1Y),Backlit Keyboard,Office 2024,Silver,1.88 kg,X1605VA-SH1952WS, Thin & Light Laptop', "HP 15, AMD Ryzen 5 7520U,(16GB LPDDR5, 512GB SSD), Anti-Glare, Micro-Edge, FHD, 15.6''/39.6cm, Win 11, Office 24,M365 Basic(1yr)*,Silver, 1.59kg, fc0690au, FHD Camera, Backlit KB Laptop", 'Lenovo V15 G4 AMD Athlon Silver 7120U Laptop 8GB LPDDR5 Ram, 512 GB SSD PCIe, Windows 11 Lifetime Validity,15.6" FHD Screen, AMD Radeon 610M, Silver, 1 Year Brand Warranty', 'More results', 'Dell 15, 13th Gen Intel Core i5-1334U (16GB DDR4, 512GB SSD) Anti-Glare FHD 15.6"/39.62cm, Windows 11, Microsoft Office Home 2024, Grey, 1.66kg, [Vostro 3530], 12 Month McAfee, Thin & Light Laptop', 'Acer Smartchoice Aspire One, Intel Core Celeron N4500, Office 2024 + M365 Basic, 12GB LPDDR4X / 512GB SSD, 14.0"/35.56cm TN HD Display, Win 11 Home, Pure Silver, 1.3KG, A114-45, Thin and Light Laptop', 'Dell 15 (Previo
# ...

# %%
print(ratings)
# Out:
# ['4.2', '4.0', '4.0', '3.8', '3.3', '4.0', '4.2', '4.8', '4.1', '3.4', '4.1', '3.7', '2.7', '& Up']

# %%
print(price)
# Out:
# ['63,990', '54,690', '43,999', '59,990', '39,990', '50,490', '72,120', '49,480', '68,990', '63,990', '49,750', '41,990', '16,990', '86,990', '64,990', '30,990']

# %%
len(laptops)
# Out:
# 17

# %%
len(ratings)
# Out:
# 14

# %%
len(price)
# Out:
# 16

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Laptop':laptops[:14],
    'Ratings':ratings,
    'prices':price[:14]
})
df
# Out:
#                                                Laptop Ratings  prices
# 0   ASUS Vivobook 16,Smartchoice, 13th Gen, Intel ...     4.2  63,990
# 1   HP 15, AMD Ryzen 5 7520U,(16GB LPDDR5, 512GB S...     4.0  54,690
# 2   Lenovo V15 G4 AMD Athlon Silver 7120U Laptop 8...     4.0  43,999
# 3                                        More results     3.8  59,990
# 4   Dell 15, 13th Gen Intel Core i5-1334U (16GB DD...     3.3  39,990
# 5   Acer Smartchoice Aspire One, Intel Core Celero...     4.0  50,490
# 6   Dell 15 (Previously Inspiron) Laptop, 14th Gen...     4.2  72,120
# 7   acer Aspire 7, Intel Core 5-210H Processor, NV...     4.8  49,480
# 8   HP 15, 13th Gen Intel Core i3-1315U Laptop (8G...     4.1  68,990
# 9   ASUS TUF A15 (2025), AMD Ryzen 7 7445HS,RTX 30...     3.4  63,990
# 10  Apple 2026 MacBook Neo 13″ Laptop with A18 Pro...     4.1  49,750
# 11  Lenovo IdeaPad 1 AMD Ryzen 5 5500U 15.6" HD Th...     3.7  41,990
# ...

# %%
df.to_csv('data.csv')
