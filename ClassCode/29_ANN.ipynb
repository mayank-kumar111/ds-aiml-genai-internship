# %% [markdown]
# # ANN
# ![image.png](attachment:dc1a1239-da39-4002-a9e6-ce80494e0ed5.png)

# %% [markdown]
# - Artificial Neural Networks (ANNs) are computer programs inspired by how the human brain works.
# - Our brain uses neurons to process information and make decisions. In the same way, ANNs use artificial neurons to look at data, find patterns, and make predictions.
#
# - ANNs are made up of layers of these artificial neurons that are connected to each other. All these neurons work together to solve problems.
#
# - The main idea is that ANNs can learn from data, just like our brain learns from experience.
#
# - They are used in many real-life applications—like recognizing images, understanding speech, or giving personalized suggestions (like Netflix or YouTube recommendations).

# %% [markdown]
# # Key Components of an ANN
# - Input Layer: This is where the network receives information. For example, in an image recognition task, the input could be an image.
# - Hidden Layers: These layers process the data received from the input layer. The more hidden layers there are, the more complex patterns the network can learn and understand. Each hidden layer transforms the data into more abstract information.
# - Output Layer: This is where the final decision or prediction is made. For example, after processing an image, the output layer might decide whether it’s a cat or a dog.

# %% [markdown]
# # Working of Artificial Neural Networks
#
#
# ANNs work by learning patterns in data through a process called training. During training, the network adjusts itself to improve its accuracy by comparing its predictions with the actual results
# - Input Layer: Data such as an image, text or number is fed into the network through the input layer.
# - Hidden Layers: Each neuron in the hidden layers performs some calculation on the input, passing the result to the next layer. The data is transformed and abstracted at each layer.
# - Output Layer: After passing through all the layers, the network gives its final prediction like classifying an image as a cat or a dog.

# %% [markdown]
# The process of backpropagation is used to adjust the weights between neurons. When the network makes a mistake, the weights are updated to reduce the error and improve the next prediction.

# %% [markdown]
# # How do Artificial Neural Networks learn?
# - Artificial Neural Networks (ANNs) learn by training on a set of data. For example, to teach an ANN to recognize a cat, we show it thousands of images of cats. The network processes these images and learns to identify the features that define a cat.
# - Once the network has been trained, we test it by providing new images to see if it can correctly identify cats. The network’s prediction is then compared to the actual label (whether it's a cat or not). If it makes an incorrect prediction, the network adjusts by fine-tuning the weights of the connections between neurons using a process called backpropagation. This involves correcting the weights based on the difference between the predicted and actual result.
# - This process repeats until the network can accurately recognize a cat in an image with minimal error. Essentially, through constant training and feedback, the network becomes better at identifying patterns and making predictions.ns.

# %% [markdown]
# ![image.png](attachment:c441dd16-882c-4310-b98e-0c7c26edd02a.png)

# %% [markdown]
# # Types of Artificial Neural Networks

# %% [markdown]
# ### 1. Feedforward Neural Network (FNN)
# Feedforward Neural Networks are one of the simplest types of ANNs. In this network, data flows in one direction from the input layer to the output layer, passing through one or more hidden layers. There are no loops or cycles means the data doesn’t return to any earlier layers. This type of network does not use backpropagation and is mainly used for basic classification and regression tasks.
#
# ![image.png](attachment:b813da74-fc09-4f5b-a79b-f226654406b1.png)

# %% [markdown]
# ### 2. Convolutional Neural Network (CNN)
# Convolutional Neural Networks (CNNs) are designed to process data that has a grid-like structure such as images. It include convolutional layers that apply filters to extract important features from the data such as edges or textures. This makes CNNs effective in image and speech recognition as they can identify patterns and structures in complex data.
#
# ![image.png](attachment:f43f9f13-1b94-41b0-8451-30a3ca0755df.png)

# %% [markdown]
# ### 3. Recurrent Neural Network (RNN)
# Recurrent Neural Networks are designed to handle sequential data such as time-series or text. Unlike other networks, RNNs have feedback loops that allow information to be passed back into previous layers, giving the network memory. This feature helps RNNs to make predictions based on the context provided by previous data helps in making them ideal for tasks like speech recognition, language modeling and forecasting.
#
# ![image.png](attachment:b389e6b5-afbf-4615-9514-866d943d932d.png)

# %% [markdown]
# # Optimization Algorithms in ANN Training
# Optimization algorithms adjust the weights of a neural network during training to minimize errors. The goal is to make the network’s predictions more accurate.
# - **Gradient Descent**: Most basic optimization algorithm that updates weights by calculating the gradient of the loss function.
# - **Adam (Adaptive Moment Estimation)**: An efficient version of gradient descent that adapts learning rates for each weight used in deep learning.
# - **RMSprop**: A variation of gradient descent that adjusts the learning rate based on the average of recent gradients, it is useful in training recurrent neural networks (RNNs).
# - **Stochastic Gradient Descent (SGD)**: Updates weights using one sample at a time helps in making it faster but more noisy.

# %% [markdown]
# ![image.png](attachment:f6b60a2c-5aec-4d0c-9f23-f6282c689cd5.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import csv

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('D:\\Internship\\ds-aiml-genai-internship\\DeepLearning\\BreastCancer.csv',  sep=',', quoting=csv.QUOTE_NONE, engine='python')
data
# Out:
#            "id ""diagnosis""  ""radius_mean""  ""texture_mean""  \
# 0      "842302             M            17.99             10.38
# 1      "842517             M            20.57             17.77
# 2    "84300903             M            19.69             21.25
# 3    "84348301             M            11.42             20.38
# 4    "84358402             M            20.29             14.34
# ..         ...           ...              ...               ...
# 564    "926424             M            21.56             22.39
# 565    "926682             M            20.13             28.25
# 566    "926954             M            16.60             28.08
# 567    "927241             M            20.60             29.33
# 568     "92751             B             7.76             24.54
#
#      ""perimeter_mean""  ""area_mean""  ""smoothness_mean""  \
# 0                122.80         1001.0              0.11840
# 1                132.90         1326.0              0.08474
# 2                130.00         1203.0              0.10960
# 3                 77.58          386.1              0.14250
# 4                135.10         1297.0              0.10030
# ..                  ...            ...                  ...
# 564              142.00         1479.0              0.11100
# 565              131.20         1261.0              0.09780
# 566              108.30          858.1              0.08455
# 567              140.10         1265.0              0.11780
# 568               47.92          181.0              0.05263
#
#      ""compactness_mean""  ""concavity_mean""  ""concave points_mean""  ...  \
# 0                 0.27760             0.30010                  0.14710  ...
# 1                 0.07864             0.08690                  0.07017  ...
# 2                 0.15990             0.19740                  0.12790  ...
# 3                 0.28390             0.24140                  0.10520  ...
# 4                 0.13280             0.19800                  0.10430  ...
# ..                    ...                 ...                      ...  ...
# 564               0.11590             0.24390                  0.13890  ...
# 565               0.10340             0.14400                  0.09791  ...
# 566               0.10230             0.09251                  0.05302  ...
# 567               0.27700             0.35140                  0.15200  ...
# 568               0.04362             0.00000                  0.00000  ...
#
#      ""texture_worst""  ""perimeter_worst""  ""area_worst""  \
# 0                17.33               184.60          2019.0
# 1                23.41               158.80          1956.0
# 2                25.53               152.50          1709.0
# 3                26.50                98.87           567.7
# 4                16.67               152.20          1575.0
# ..                 ...                  ...             ...
# 564              26.40               166.10          2027.0
# 565              38.25               155.00          1731.0
# 566              34.12               126.70          1124.0
# 567              39.42               184.60          1821.0
# 568              30.37                59.16           268.6
#
#      ""smoothness_worst""  ""compactness_worst""  ""concavity_worst""  \
# 0                 0.16220                0.66560               0.7119
# 1                 0.12380                0.18660               0.2416
# 2                 0.14440                0.42450               0.4504
# 3                 0.20980                0.86630               0.6869
# 4                 0.13740                0.20500               0.4000
# ..                    ...                    ...                  ...
# 564               0.14100                0.21130               0.4107
# 565               0.11660                0.19220               0.3215
# 566               0.11390                0.30940               0.3403
# 567               0.16500                0.86810               0.9387
# 568               0.08996                0.06444               0.0000
#
#      ""concave points_worst""  ""symmetry_worst""  \
# 0                      0.2654              0.4601
# 1                      0.1860              0.2750
# 2                      0.2430              0.3613
# 3                      0.2575              0.6638
# 4                      0.1625              0.2364
# ..                        ...                 ...
# 564                    0.2216              0.2060
# 565                    0.1628              0.2572
# 566                    0.1418              0.2218
# 567                    0.2650              0.4087
# 568                    0.0000              0.2871
#
#      ""fractal_dimension_worst""   "
# 0                        0.1189" NaN
# 1                       0.08902" NaN
# 2                       0.08758" NaN
# 3                         0.173" NaN
# 4                       0.07678" NaN
# ..                           ...  ..
# 564                     0.07115" NaN
# 565                     0.06637" NaN
# 566                      0.0782" NaN
# 567                       0.124" NaN
# 568                     0.07039" NaN
#
# [569 rows x 33 columns]

# %%
# Remove the extra quotation marks
data.columns = data.columns.str.strip('"')
data = data.map(lambda x: x.strip('"') if isinstance(x, str) else x)

print(data.shape)
print(data.columns.tolist())
print(data.head())
# Out:
# (569, 33)
# ['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst', '']
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst
# 0                   0.1189 NaN
# 1                  0.08902 NaN
# 2                  0.08758 NaN
# 3                    0.173 NaN
# 4                  0.07678 NaN
#
# [5 rows x 33 columns]

# %%
sns.countplot(x='diagnosis', data=data, palette='Set2')
plt.title('Tumor Type Distribution')
plt.show()
# Out:
# C:\Users\Mayan\AppData\Local\Temp\ipykernel_28944\394012108.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='diagnosis', data=data, palette='Set2')

# %%
sns.countplot(
    x='diagnosis',
    data=data,
    hue='diagnosis',
    palette='Set2',
    legend=False
)

plt.title('Tumor Type Distribution')
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.show()

# %%
X = data.iloc[:, 2:-1]
y = data['diagnosis'].map({'B': 0, 'M': 1})

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
np.random.seed(1)
input_neurons = X_train.shape[1]   # number of features in data
hidden_neurons = 10                # neurons in hidden layer
output_neurons = 1                 # final yes/no prediction (cancer or not)
lr = 0.01                          # learning rate (small step size)
epochs = 500                       # how many times to train


# random weights and zero biases
W1 = np.random.randn(input_neurons, hidden_neurons)  
b1 = np.zeros((1, hidden_neurons))  

W2 = np.random.randn(hidden_neurons, output_neurons)  
b2 = np.zeros((1, output_neurons))  


def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def sigmoid_derivative(a):
    return a * (1 - a)

def loss(y_true, y_pred):
    return -np.mean(y_true*np.log(y_pred) + (1 - y_true)*np.log(1 - y_pred))

# %%
losses = []

for epoch in range(epochs):
    # Forward
    Z1 = np.dot(X_train, W1) + b1
    A1 = sigmoid(Z1)

    Z2 = np.dot(A1, W2) + b2
    A2 = sigmoid(Z2)

    # Loss
    train_loss = loss(y_train.values.reshape(-1, 1), A2)
    losses.append(train_loss)

    # Backward
    dZ2 = A2 - y_train.values.reshape(-1, 1)
    dW2 = np.dot(A1.T, dZ2)
    db2 = np.sum(dZ2, axis=0, keepdims=True)

    dA1 = np.dot(dZ2, W2.T)
    dZ1 = dA1 * sigmoid_derivative(A1)
    dW1 = np.dot(X_train.T, dZ1)
    db1 = np.sum(dZ1, axis=0, keepdims=True)

    # Update
    W1 -= lr * dW1
    b1 -= lr * db1
    W2 -= lr * dW2
    b2 -= lr * db2

    if epoch % 50 == 0:
        print(f"Epoch {epoch}: Loss = {train_loss:.4f}")
# Out:
# Epoch 0: Loss = 1.5318
# Epoch 50: Loss = 0.0505
# Epoch 100: Loss = 0.0330
# Epoch 150: Loss = 0.0237
# Epoch 200: Loss = 0.0176
# Epoch 250: Loss = 0.0128
# Epoch 300: Loss = 0.0102
# Epoch 350: Loss = 0.0083
# Epoch 400: Loss = 0.0070
# Epoch 450: Loss = 0.0059

# %%
plt.plot(losses)
plt.title("Training Loss over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid()
plt.show()

# %% [markdown]
# ## Y-axis (Loss):
# - Shows how much the model's predictions deviate from the actual values.
# - Lower = Better.
# ## X-axis (Epochs):
# - The number of training cycles (complete passes through the training dataset).
# ## The Curve Behavior:
# - Initially (Epoch 0–50):
#   - The loss drops sharply — this means the model is learning quickly in the beginning.
# - After ~50 Epochs:
#   - The loss continues to decrease slowly — the model is still learning, but at a reduced rate.
# - After ~200+ Epochs:
#   -  The curve almost flattens — meaning the model is nearing convergence (minimal improvement).

# %%
# Predict
Z1 = np.dot(X_test, W1) + b1
A1 = sigmoid(Z1)
Z2 = np.dot(A1, W2) + b2
A2 = sigmoid(Z2)
predictions = (A2 > 0.5).astype(int)

# Accuracy
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Accuracy:", accuracy_score(y_test, predictions))
print("\nClassification Report:\n", classification_report(y_test, predictions))

# Confusion Matrix
sns.heatmap(confusion_matrix(y_test, predictions), annot=True, fmt='d', cmap='coolwarm')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Accuracy: 0.9736842105263158
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98        71
#            1       0.95      0.98      0.97        43
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %%
from sklearn.neural_network import MLPClassifier

clf = MLPClassifier(hidden_layer_sizes=(10,), max_iter=300, random_state=42)
clf.fit(X_train, y_train)
y_pred_sklearn = clf.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred_sklearn))
# Out:
# Accuracy: 0.9736842105263158
# e:\App\Anaconda\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# Train sklearn's MLPClassifier
clf = MLPClassifier(hidden_layer_sizes=(10,), max_iter=500, random_state=42)
clf.fit(X_train, y_train)
y_pred_sklearn = clf.predict(X_test)

# Accuracy
acc_manual = accuracy_score(y_test, predictions)
acc_sklearn = accuracy_score(y_test, y_pred_sklearn)

print("Manual Neural Network Accuracy:", acc_manual)
print("Sklearn MLPClassifier Accuracy:", acc_sklearn)
# Out:
# Manual Neural Network Accuracy: 0.9736842105263158
# Sklearn MLPClassifier Accuracy: 0.9824561403508771

# %%
# Manual NN Confusion Matrix
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.heatmap(confusion_matrix(y_test, predictions), annot=True, fmt='d', cmap='Greens')
plt.title("Manual Neural Network")
plt.xlabel("Predicted")
plt.ylabel("Actual")

# Sklearn NN Confusion Matrix
plt.subplot(1, 2, 2)
sns.heatmap(confusion_matrix(y_test, y_pred_sklearn), annot=True, fmt='d', cmap='Blues')
plt.title("Sklearn MLPClassifier")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.tight_layout()
plt.show()

# %%
# Accuracy Comparison
models = ['Manual NN', 'Sklearn MLP']
accuracies = [acc_manual, acc_sklearn]

plt.figure(figsize=(6,4))
plt.bar(models, accuracies, color=['orange', 'skyblue'])
plt.ylim(0.8, 1.0)
plt.ylabel("Accuracy")
plt.title("Model Accuracy Comparison")
for i, v in enumerate(accuracies):
    plt.text(i, v + 0.005, f"{v:.2f}", ha='center', fontweight='bold')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
plt.plot(losses)
plt.title("Manual Neural Network - Training Loss over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid()
plt.show()

# %%
import pandas as pd

comparison_df = pd.DataFrame({
    'Model': ['Manual Neural Network', 'Sklearn MLPClassifier'],
    'Accuracy': [acc_manual, acc_sklearn]
})

print(comparison_df)
# Out:
#                    Model  Accuracy
# 0  Manual Neural Network  0.973684
# 1  Sklearn MLPClassifier  0.982456
