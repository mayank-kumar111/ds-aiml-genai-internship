# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
house = pd.read_csv("Housing.csv")
house
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
X = house.drop('median_house_value', axis=1)
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
y = house.median_house_value
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20640, dtype: float64

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20640, dtype: float64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
# dtypes: float64(8), object(1)
# memory usage: 1.4+ MB

# %%
X.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
X.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# dtype: int64

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20640, dtype: float64

# %%
house
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
house['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
house.groupby('ocean_proximity')

# %%
house.groupby('ocean_proximity').groups
# Out:
# {'<1H OCEAN': [701, 830, 859, 860, 861, 862, 863, 870, 880, 881, 882, 883, 884, 885, 886, 887, 888, 889, 890, 891, 892, 893, 894, 895, 896, 897, 898, 899, 900, 901, 902, 903, 904, 905, 906, 907, 908, 910, 912, 914, 915, 916, 917, 918, 919, 920, 921, 922, 923, 924, 925, 926, 927, 945, 946, 947, 948, 949, 950, 951, 952, 953, 955, 956, 958, 959, 960, 961, 962, 963, 964, 966, 971, 972, 978, 989, 1542, 1543, 1544, 1545, 1546, 1547, 1548, 1549, 1550, 1551, 1552, 1553, 1554, 1555, 1556, 1557, 1558, 1559, 1560, 1561, 1562, 1563, 1564, 1565, ...], 'INLAND': [954, 957, 965, 967, 968, 969, 970, 973, 974, 975, 976, 977, 979, 980, 981, 982, 983, 984, 985, 986, 987, 988, 990, 991, 992, 993, 994, 995, 996, 997, 998, 999, 1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1035, 1036, 1037, 1038, 1039, 1040, 1041, 1042, 1043, 1044, 1045, 1046, 
# ...

# %%
house.groupby('ocean_proximity')[['median_house_value']].mean()
# Out:
#                  median_house_value
# ocean_proximity
# <1H OCEAN             240084.285464
# INLAND                124805.392001
# ISLAND                380440.000000
# NEAR BAY              259212.311790
# NEAR OCEAN            249433.977427

# %%
(house.groupby('ocean_proximity')[['median_house_value']].mean()).sort_values(by='median_house_value')
# Out:
#                  median_house_value
# ocean_proximity
# INLAND                124805.392001
# <1H OCEAN             240084.285464
# NEAR OCEAN            249433.977427
# NEAR BAY              259212.311790
# ISLAND                380440.000000

# %%
(house.groupby('ocean_proximity')[['median_house_value']].mean()).sort_values(by='median_house_value', ascending=False)
# Out:
#                  median_house_value
# ocean_proximity
# ISLAND                380440.000000
# NEAR BAY              259212.311790
# NEAR OCEAN            249433.977427
# <1H OCEAN             240084.285464
# INLAND                124805.392001

# %%
plt.figure(figsize=(12,8), dpi=150)
sns.scatterplot(x=house['longitude'], y=house['latitude'])
plt.show()

# %%
plt.figure(figsize=(12,8), dpi=150)
sns.scatterplot(x=house['longitude'], y=house['latitude'], hue=house['ocean_proximity'])
plt.show()

# %%
house['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20640, dtype: float64

# %% [markdown]
# ### Random Sampling

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2, random_state=121)

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5800     -118.24     34.15                 7.0       2063.0           670.0
# 601      -122.08     37.70                25.0       3402.0           758.0
# 10379    -117.64     33.65                 4.0       6842.0          1512.0
# 20405    -118.88     34.21                26.0       1590.0           196.0
# 7170     -118.19     34.06                37.0       1715.0           456.0
# ...          ...       ...                 ...          ...             ...
# 19198    -122.69     38.44                31.0       1808.0           315.0
# 3583     -118.55     34.23                25.0       4409.0          1018.0
# 18497    -121.54     36.99                27.0       2361.0           449.0
# 4565     -118.26     34.07                40.0        680.0           273.0
# 11586    -118.01     33.79                30.0       2460.0           403.0
#
# ...

# %%
y_train
# Out:
# 5800     202300.0
# 601      209900.0
# 10379    216600.0
# 20405    300000.0
# 7170     116100.0
#            ...
# 19198    193200.0
# 3583     245100.0
# 18497    305000.0
# 4565     165600.0
# 11586    223200.0
# Name: median_house_value, Length: 16512, dtype: float64

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16818    -122.46     37.65                16.0       8676.0          1633.0
# 18306    -122.11     37.43                35.0       3905.0           565.0
# 549      -122.25     37.77                52.0       2156.0           458.0
# 4239     -118.32     34.11                42.0       2462.0           543.0
# 6084     -117.89     34.09                36.0       1811.0           320.0
# ...          ...       ...                 ...          ...             ...
# 6460     -118.05     34.10                36.0       1606.0           318.0
# 18375    -121.85     37.22                21.0       6203.0           798.0
# 11212    -117.91     33.82                29.0       1444.0           326.0
# 20291    -119.19     34.17                35.0       4276.0           767.0
# 6340     -117.90     33.98                20.0       9893.0          2283.0
#
# ...

# %%
y_test
# Out:
# 16818    262000.0
# 18306    463700.0
# 549      254200.0
# 4239     434400.0
# 6084     188300.0
#            ...
# 6460     272600.0
# 18375    362700.0
# 11212    182900.0
# 20291    187300.0
# 6340     186700.0
# Name: median_house_value, Length: 4128, dtype: float64

# %%
X['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
(X['ocean_proximity'].value_counts() / X.shape[0]) * 100
# Out:
# ocean_proximity
# <1H OCEAN     44.263566
# INLAND        31.739341
# NEAR OCEAN    12.877907
# NEAR BAY      11.094961
# ISLAND         0.024225
# Name: count, dtype: float64

# %%
X.shape[0]
# Out:
# (20640, 9)

# %%
X.shape[0]
# Out:
# 20640

# %%
(X_train['ocean_proximity'].value_counts() / X_train.shape[0]) * 100
# Out:
# ocean_proximity
# <1H OCEAN     44.507025
# INLAND        31.686047
# NEAR OCEAN    12.808866
# NEAR BAY      10.973837
# ISLAND         0.024225
# Name: count, dtype: float64

# %%
(X_test['ocean_proximity'].value_counts() / X_test.shape[0]) * 100
# Out:
# ocean_proximity
# <1H OCEAN     43.289729
# INLAND        31.952519
# NEAR OCEAN    13.154070
# NEAR BAY      11.579457
# ISLAND         0.024225
# Name: count, dtype: float64

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20640, dtype: float64

# %% [markdown]
# ### Stratified sampling

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
s = StratifiedShuffleSplit(n_splits=10, test_size=0.2, random_state=121)
s
# Out:
# StratifiedShuffleSplit(n_splits=10, random_state=121, test_size=0.2,
#             train_size=None)

# %%
obj = s.split(X, X['ocean_proximity'])
obj
# Out:
# <generator object BaseShuffleSplit.split at 0x0000018E92F8DD40>

# %%
for i in obj:
    print(i)
    print()
# Out:
# (array([ 1189,  3831, 18624, ..., 12253,  3824, 16591], dtype=int64), array([  904, 12611, 20520, ...,   279, 12241, 16211], dtype=int64))
#
# (array([10509, 14816,  4695, ...,  6640, 13332, 20222], dtype=int64), array([ 6653,  4993, 12424, ...,  8795,  9249,  7735], dtype=int64))
#
# (array([ 7024,  3830,   754, ...,  9883,  6225, 15515], dtype=int64), array([9315, 9924, 8851, ..., 1204, 2288, 9828], dtype=int64))
#
# (array([10529,  3972, 11112, ...,  8044,  7286,  5357], dtype=int64), array([14221,   523,  4207, ..., 13806, 14897,  9526], dtype=int64))
#
# (array([19598,  4878,  3395, ...,  6482, 10325,  1739], dtype=int64), array([ 7771, 12988, 19402, ..., 16979,  9981, 10626], dtype=int64))
#
# (array([16269, 13519,  1182, ..., 19713, 11405,  8015], dtype=int64), array([18032, 18875, 16270, ..., 15761,  4094, 14618], dtype=int64))
#
# (array([11454, 18317, 12294, ..., 14889,   345, 18641], dtype=int64), array([ 6384, 10222,  4423, ...,  8969,  2738,  5729], dtype=int64))
#
# ...

# %%
c = 1
for i in s.split(X, X['ocean_proximity']):
    print(f"Split: {c}")
    print(i)
    print()
    c += 1
# Out:
# Split: 1
# (array([ 1189,  3831, 18624, ..., 12253,  3824, 16591], dtype=int64), array([  904, 12611, 20520, ...,   279, 12241, 16211], dtype=int64))
#
# Split: 2
# (array([10509, 14816,  4695, ...,  6640, 13332, 20222], dtype=int64), array([ 6653,  4993, 12424, ...,  8795,  9249,  7735], dtype=int64))
#
# Split: 3
# (array([ 7024,  3830,   754, ...,  9883,  6225, 15515], dtype=int64), array([9315, 9924, 8851, ..., 1204, 2288, 9828], dtype=int64))
#
# Split: 4
# (array([10529,  3972, 11112, ...,  8044,  7286,  5357], dtype=int64), array([14221,   523,  4207, ..., 13806, 14897,  9526], dtype=int64))
#
# Split: 5
# (array([19598,  4878,  3395, ...,  6482, 10325,  1739], dtype=int64), array([ 7771, 12988, 19402, ..., 16979,  9981, 10626], dtype=int64))
#
# Split: 6
# (array([16269, 13519,  1182, ..., 19713, 11405,  8015], dtype=int64), array([18032, 18875, 16270, ..., 15761,  4094, 14618], dtype=int64))
#
# Split: 7
# ...

# %%
c = 1
for i,j in s.split(X, X['ocean_proximity']):
    print(f"Split: {c}")
    print(f"Train_idx: {i}")
    print(f"Test_idx: {j}")
    print()
    c += 1
# Out:
# Split: 1
# Train_idx: [ 1189  3831 18624 ... 12253  3824 16591]
# Test_idx: [  904 12611 20520 ...   279 12241 16211]
#
# Split: 2
# Train_idx: [10509 14816  4695 ...  6640 13332 20222]
# Test_idx: [ 6653  4993 12424 ...  8795  9249  7735]
#
# Split: 3
# Train_idx: [ 7024  3830   754 ...  9883  6225 15515]
# Test_idx: [9315 9924 8851 ... 1204 2288 9828]
#
# Split: 4
# Train_idx: [10529  3972 11112 ...  8044  7286  5357]
# Test_idx: [14221   523  4207 ... 13806 14897  9526]
#
# Split: 5
# Train_idx: [19598  4878  3395 ...  6482 10325  1739]
# Test_idx: [ 7771 12988 19402 ... 16979  9981 10626]
#
# Split: 6
# Train_idx: [16269 13519  1182 ... 19713 11405  8015]
# Test_idx: [18032 18875 16270 ... 15761  4094 14618]
#
# Split: 7
# Train_idx: [11454 18317 12294 ... 14889   345 18641]
# Test_idx: [ 6384 10222  4423 ...  8969  2738  5729]
#
# Split: 8
# Train_idx: [18698  3934 14191 ...  7861  2206  3926]
# Test_idx: [ 8923  4562  9306 ...  8308  2774 18474]
#
# Split: 9
# ...

# %%
s = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=121)
obj = s.split(X, X['ocean_proximity'])
obj
# Out:
# <generator object BaseShuffleSplit.split at 0x0000018E92F8EB40>

# %%
train_idx, test_idx = obj.__next__()

# %%
train_idx
# Out:
# array([ 1189,  3831, 18624, ..., 12253,  3824, 16591], dtype=int64)

# %%
test_idx
# Out:
# array([  904, 12611, 20520, ...,   279, 12241, 16211], dtype=int64)

# %%
len(train_idx)
# Out:
# 16512

# %%
len(test_idx)
# Out:
# 4128

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20640, dtype: float64

# %%
X_train = X.iloc[train_idx]
X_test = X.iloc[test_idx]
y_train = y.iloc[train_idx]
y_test = y.iloc[test_idx]

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1189     -121.52     39.43                15.0       2119.0           389.0
# 3831     -118.43     34.20                29.0       3051.0           694.0
# 18624    -122.01     37.06                19.0       4113.0           767.0
# 19905    -119.27     36.32                 6.0       2881.0           518.0
# 9523     -123.10     39.15                32.0       1143.0           208.0
# ...          ...       ...                 ...          ...             ...
# 5405     -118.44     34.03                37.0        975.0           189.0
# 6958     -118.06     34.00                34.0       5002.0           917.0
# 12253    -117.02     33.73                14.0       3700.0           750.0
# 3824     -118.47     34.19                33.0       3879.0           943.0
# 16591    -121.44     37.73                 7.0       8363.0          1314.0
#
# ...

# %%
y_train
# Out:
# 1189      80400.0
# 3831     238100.0
# 18624    308100.0
# 19905    110200.0
# 9523     116100.0
#            ...
# 5405     331000.0
# 6958     219800.0
# 12253    112500.0
# 3824     292900.0
# 16591    208100.0
# Name: median_house_value, Length: 16512, dtype: float64

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 904      -121.99     37.54                26.0       2332.0           371.0
# 12611    -121.52     38.53                31.0       3089.0           585.0
# 20520    -121.53     38.58                35.0       1316.0           321.0
# 12690    -121.37     38.57                22.0       4899.0           847.0
# 8778     -118.31     33.80                31.0       4464.0           991.0
# ...          ...       ...                 ...          ...             ...
# 1340     -121.90     38.02                12.0       1497.0           360.0
# 343      -122.19     37.75                36.0       1126.0           263.0
# 279      -122.18     37.81                37.0       1643.0           262.0
# 12241    -116.97     33.74                31.0       2712.0           628.0
# 16211    -121.31     37.96                52.0       1938.0           332.0
#
# ...

# %%
y_test
# Out:
# 904      225000.0
# 12611    160300.0
# 20520     79200.0
# 12690    387000.0
# 8778     277900.0
#            ...
# 1340     122200.0
# 343       82800.0
# 279      336700.0
# 12241     86200.0
# 16211    118400.0
# Name: median_house_value, Length: 4128, dtype: float64

# %%
(X_train['ocean_proximity'].value_counts() / X_train.shape[0]) * 100
# Out:
# ocean_proximity
# <1H OCEAN     44.264777
# INLAND        31.740552
# NEAR OCEAN    12.875484
# NEAR BAY      11.094961
# ISLAND         0.024225
# Name: count, dtype: float64

# %%
X_train['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7309
# INLAND        5241
# NEAR OCEAN    2126
# NEAR BAY      1832
# ISLAND           4
# Name: count, dtype: int64

# %%
(X_test['ocean_proximity'].value_counts() / X_test.shape[0]) * 100
# Out:
# ocean_proximity
# <1H OCEAN     44.258721
# INLAND        31.734496
# NEAR OCEAN    12.887597
# NEAR BAY      11.094961
# ISLAND         0.024225
# Name: count, dtype: float64

# %%
X_test['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     1827
# INLAND        1310
# NEAR OCEAN     532
# NEAR BAY       458
# ISLAND           1
# Name: count, dtype: int64
